# %% [markdown]
# # Circuit Simulation Plots Viewer
# This notebook displays the generated circuit simulation plots.

# %%
from IPython.display import Image, display
import os

# List all plot files
plot_dir = '../examples/output/'
plot_files = [f for f in os.listdir(plot_dir) if f.endswith('.png')]
plot_files.sort()

print(f"Found {len(plot_files)} plot files:")
for f in plot_files:
    print(f"  • {f}")

# %% [markdown]
# ## 1. Voltage Divider DC Analysis

# %%
display(Image('../examples/output/voltage_divider.png'))

# %% [markdown]
# ## 2. RC Circuit Charging Curve

# %%
display(Image('../examples/output/rc_charging.png'))

# %% [markdown]
# ## 3. RL Circuit Response

# %%
display(Image('../examples/output/rl_response.png'))

# %% [markdown]
# ## 4. RC Filter Frequency Response

# %%
display(Image('../examples/output/rc_filter.png'))

# %% [markdown]
# ## 5. RC Time Constant Comparison

# %%
display(Image('../examples/output/rc_comparison.png'))
